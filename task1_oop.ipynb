# %% [markdown]
# import the file

# %%
from bank_opp import ATM

# %% [markdown]
# Create object from the class

# %%
user = ATM("mohamed", 20)

# %% [markdown]
# Add money to account

# %%
user.deposit(1000)
# Out:
# Acount Balance has been update : $ 1000

# %% [markdown]
# Withdraw form the account

# %%
# True
user.withdraw(100)
# Out:
# Acount Balance has been update : $900

# %%
#False
user.withdraw(30000)
# Out:
# You not have enough money
# the operation is done you are indebted to the bank with 299100

# %% [markdown]
# View account informtion

# %%
user.view_balance()
# Out:
# Name is : mohamed
# Age is : 20
#
# Acount Balance is : $ 900
